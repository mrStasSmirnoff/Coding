# %% [markdown]
# ## 1) Sorting: Bubble Sort
# Given an array of integers, sort the array in ascending order using the Bubble Sort algorithm above.

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the countSwaps function below.
def countSwaps(a):
    
    count = 0
    for i in range(len(a)):
        for j in range(len(a)-1):
            
             #Swap adjacent elements if they are in decreasing order
            if (a[j] > a[j+1]):
                 
                 temp = a[j]
                 a[j] = a[j+1]
                 a[j+1]  = temp
                 count += 1
            
    return (a[0], a[-1], count)
                 
   
    
if __name__ == '__main__':
    n = int(input())

    a = list(map(int, input().rstrip().split()))

    first, last, swaps = countSwaps(a)
                 
    print("Array is sorted in", swaps, "swaps.")
    print("First Element:", first)
    print("Last Element:", last)

# %% [markdown]
# ## 2) Mark and Toys
#
# Mark and Jane are very happy after having their first child. Their son loves toys, so Mark wants to buy some. There are a number of different toys lying in front of him, tagged with their prices. Mark has only a certain amount to spend, and he wants to maximize the number of toys he buys with this money.

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

def bubble_sorting(a):
    
    for i in range(len(a)):
        
        for j in range(len(a) - 1):
            
            if a[j] >  a[j+1]:
                
                temp = a[j]
                a[j] = a[j+1]
                a[j+1] = temp
                
    return a

# Complete the maximumToys function below.

# First of all we need to sort an array so lets define bubble sort again here.
# Actually we could used in build .sort() method (which uses Timsort algo - mixture of Insertion 
# and merge sort) as an alternative. The sorting with bubble sort will not pass time limits in the test
# cases. Therefore the final code includes .sort() method.

def maximumToys(prices, k):
    
    #sorted_prices = bubble_sorting(prices)
    
    sorted_prices = prices.sort()
    toys = 0
    index = 0
    
    #while k > sorted_prices[index]:
    
    while k > prices[index]:    
        k -= prices[index]
        toys += 1
        index += 1
                          
        
    return toys    
        

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    nk = input().split()

    n = int(nk[0])

    k = int(nk[1])

    prices = list(map(int, input().rstrip().split()))

    result = maximumToys(prices, k)

    fptr.write(str(result) + '\n')

    fptr.close()
